# %% [markdown]
# # Taller 9
# Métodos Computacionales para Políticas Públicas - URosario
#
# **Entrega: viernes 28-oct-2016 11:59 PM**

# %% [markdown]
# <div class="alert alert-success">
# **[Nathalie Basto Aguirre]** <br><br>
# [nathaliekupa@hotmail.com]
# </div>

# %% [markdown]
# ## Instrucciones:
# - Guarde una copia de este *Jupyter Notebook* en su computador, idealmente en una carpeta destinada al material del curso.
# - Modifique el nombre del archivo del *notebook*, agregando al final un guión inferior y su nombre y apellido, separados estos últimos por otro guión inferior. Por ejemplo, mi *notebook* se llamaría: mcpp_taller9_santiago_matallana
# - Marque el *notebook* con su nombre y e-mail en el bloque verde arriba. Reemplace el texto "[Su nombre acá]" con su nombre y apellido. Similar para su e-mail.
# - Desarrolle la totalidad del taller sobre este *notebook*, insertando las celdas que sea necesario debajo de cada pregunta. Haga buen uso de las celdas para código y de las celdas tipo *markdown* según el caso.
# - Recuerde salvar periódicamente sus avances.
# - Cuando termine el taller:
#     1. Descárguelo en PDF. Si tiene algún problema con la conversión, descárguelo en HTML.
#     2. Suba todos los archivos a su repositorio en GitHub, en una carpeta destinada exclusivamente para este taller, antes de la fecha y hora límites.

# %% [markdown]
# ---

# %% [markdown]
# NLTK Book (http://www.nltk.org/book/), Exercises:
# - Chapter 1: 22, 26, 28
# - Chapter 2: 2, 4, 11

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [18.0, 8.0]

# %%
##en ipython 
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ## cap 1 punto 22 Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
fdist1=FreqDist(text5)

# %%
fdist1.most_common(10)
# Out:
# [('.', 1268),
#  ('JOIN', 1021),
#  ('PART', 1016),
#  ('?', 737),
#  ('lol', 704),
#  ('to', 658),
#  ('i', 648),
#  ('the', 646),
#  ('you', 635),
#  (',', 596)]

# %%
#V = set(text5)
fourletter_words = [w for w in text5 if len(w) == 4]
fourletter_words ##este me da una lista que contiene solo las palabras del texto 5 que tienen 4 letras
# Out:
# ['left',
#  'with',
#  'this',
#  'name',
#  'PART',
#  'well',
#  'NICK',
#  'name',
#  'U121',
#  'golf',
#  'clap',
#  'JOIN',
#  'that',
#  'nice',
#  'JOIN',
#  'PART',
#  'golf',
#  'clap',
#  'fuck',
#  'U121',
#  'PART',
#  'PART',
#  'clap',
#  'your',
#  'PART',
#  'dont',
#  'even',
#  'know',
#  'what',
#  'that',
#  'that',
#  'chat',
#  'JOIN',
#  'drew',
#  'cast',
#  'PART',
#  'sexy',
#  'U115',
#  'JOIN',
#  'PART',
#  'drew',
#  'girl',
#  'with',
#  'legs',
#  'hope',
#  'draw',
#  'PART',
#  'head',
#  'legs',
#  'JOIN',
#  'JOIN',
#  'good',
#  'JOIN',
#  'PART',
#  'take',
#  'have',
#  'docs',
#  'Slip',
#  'away',
#  'Fade',
#  'away',
#  'Days',
#  'away',
#  'feel',
#  'have',
#  'back',
#  'U115',
#  'U129',
#  'U115',
#  'chat',
#  'with',
#  'PART',
#  'JOIN',
#  'JOIN',
#  'fast',
#  'U116',
#  'bowl',
#  'bong',
#  'JOIN',
#  'well',
#  'glad',
#  'hard',
#  'from',
#  'here',
#  'back',
#  'PART',
#  'PART',
#  'JOIN',
#  'U121',
#  'name',
# ...

# %%
len(text5)
# Out:
# 45010

# %%
##len(text5)
len(fourletter_words) ## hay 10204 palabras de longitud 4 en el texto 5
# Out:
# 10204

# %%
fdist = FreqDist(len(w) for w in text5)
print(fdist)
fdist ##tambien de esta forma se puede ver que hay 10204 palabras de longitud 4
# Out:
# <FreqDist with 44 samples and 45010 outcomes>
# FreqDist({0: 1,
#           1: 6236,
#           2: 8129,
#           3: 10938,
#           4: 10204,
#           5: 3789,
#           6: 2442,
#           7: 1457,
#           8: 796,
#           9: 419,
#           10: 222,
#           11: 140,
#           12: 63,
#           13: 29,
#           14: 12,
#           15: 15,
#           16: 28,
#           17: 9,
#           18: 8,
#           19: 6,
#           20: 9,
#           21: 8,
#           22: 5,
#           23: 6,
#           24: 3,
#           25: 8,
#           26: 2,
#           27: 2,
#           28: 3,
#           29: 1,
#           30: 2,
#           31: 2,
#           32: 2,
#           34: 1,
#           35: 1,
#           36: 2,
#           37: 1,
#           38: 1,
#           43: 3,
#           50: 1,
#           51: 1,
#           54: 1,
#           67: 1,
#           70: 1})

# %%
ftext4letter=FreqDist(fourletter_words)
ftext4letter ##este me da la frecuencia de distribucion de las palabras de 4 letras sobre la lista que defini anteriormente
# Out:
# FreqDist({'FINE': 1,
#           'peek': 1,
#           'hour': 9,
#           'mine': 9,
#           'HOTT': 1,
#           'docs': 1,
#           'hall': 2,
#           'shes': 4,
#           'tenn': 1,
#           'dotn': 1,
#           'anal': 1,
#           'brad': 1,
#           'quiz': 1,
#           'fart': 4,
#           'hugs': 18,
#           'Love': 2,
#           'Road': 1,
#           'U819': 4,
#           'pimp': 1,
#           'Rofl': 1,
#           'whud': 2,
#           'push': 1,
#           'argh': 2,
#           'than': 12,
#           'wont': 11,
#           'U116': 6,
#           'When': 5,
#           'fine': 16,
#           'mean': 19,
#           'yout': 1,
#           '1.98': 1,
#           '!???': 1,
#           'hola': 3,
#           'o.k.': 1,
#           'kind': 2,
#           'YOUR': 2,
#           'WHEN': 1,
#           'city': 2,
#           'ltnc': 1,
#           'akon': 1,
#           'coat': 1,
#           'holy': 4,
#           'ROFL': 1,
# ...

# %%
import operator
sorted_x = sorted(ftext4letter.items(), key=operator.itemgetter(1)) ##aca organizo el diccionario ftext4letter por su valor osea la frecuencia

# %%
sorted_x ##pero me los da de menor freq a mayor
# Out:
# [('Meep', 1),
#  ('FINE', 1),
#  ('asks', 1),
#  ('scum', 1),
#  ('knee', 1),
#  ('AKST', 1),
#  ('dick', 1),
#  ('jude', 1),
#  ('AWAY', 1),
#  ('docs', 1),
#  ('kong', 1),
#  ('dotn', 1),
#  ('Heys', 1),
#  ('U113', 1),
#  ('WHOA', 1),
#  ('brad', 1),
#  ('U150', 1),
#  ('quiz', 1),
#  ('Road', 1),
#  ('guts', 1),
#  ('byes', 1),
#  ('Rofl', 1),
#  ('TYPR', 1),
#  ('push', 1),
#  ('Good', 1),
#  ('wood', 1),
#  ('yout', 1),
#  ('fish', 1),
#  ('hurr', 1),
#  ('!???', 1),
#  ('vamp', 1),
#  ('Long', 1),
#  ('o.k.', 1),
#  ('dojn', 1),
#  ('lust', 1),
#  ('WHEN', 1),
#  ('orta', 1),
#  ('akon', 1),
#  ('coat', 1),
#  ('Dawn', 1),
#  ('z-ro', 1),
#  ('lisa', 1),
#  ('ladz', 1),
#  ('LAst', 1),
#  ('cams', 1),
#  ('moms', 1),
#  ('Rick', 1),
#  ('woah', 1),
#  ('bong', 1),
#  ('waht', 1),
#  ('card', 1),
#  ('3:45', 1),
#  ('pwns', 1),
#  ('LONG', 1),
#  ('hooo', 1),
#  ('tenn', 1),
#  ('laid', 1),
#  ('City', 1),
#  ('Mono', 1),
#  ('9.53', 1),
#  ('U143', 1),
#  ('lung', 1),
# ...

# %%
sorted_x.reverse() ##aca los ordena de mayor a menor

# %%
sorted_x ##la palabra mas usada es JOIN que aparece 1021 veces
# Out:
# [('JOIN', 1021),
#  ('PART', 1016),
#  ('that', 274),
#  ('what', 183),
#  ('here', 181),
#  ('....', 170),
#  ('have', 164),
#  ('like', 156),
#  ('with', 152),
#  ('chat', 142),
#  ('your', 137),
#  ('good', 130),
#  ('just', 125),
#  ('lmao', 107),
#  ('know', 103),
#  ('room', 98),
#  ('from', 92),
#  ('this', 86),
#  ('well', 81),
#  ('hiya', 78),
#  ('back', 78),
#  ('they', 77),
#  ('dont', 75),
#  ('yeah', 75),
#  ('want', 71),
#  ('love', 60),
#  ('some', 58),
#  ('guys', 58),
#  ('been', 57),
#  ('talk', 56),
#  ('nice', 52),
#  ('time', 50),
#  ('when', 48),
#  ('make', 44),
#  ('haha', 44),
#  ('need', 43),
#  ('girl', 43),
#  ('U122', 42),
#  ('MODE', 41),
#  ('then', 40),
#  ('much', 40),
#  ('will', 40),
#  ('over', 39),
#  ('were', 38),
#  ('work', 38),
#  ('take', 37),
#  ('U115', 36),
#  ('song', 36),
#  ('U121', 36),
#  ('even', 35),
#  ('U156', 35),
#  ('seen', 35),
#  ('U105', 35),
#  ('does', 35),
#  ('more', 34),
#  ('damn', 34),
#  ('only', 33),
# ...

# %% [markdown]
# ## Cap 1.Ejercicio 26
#
# sum(len(w) for w in text1)
# What does the following Python code do? sum(len(w) for w in text1) Can you use it to work out the average word length of a text?
# Lo que hace este comando es dar el número total de caracteres en el text1, incluyendo signos de puntuación y espacios.
# ya que coje cada token del text1 le saca la longitud osea el numero de caracteres y luego los suma

# %%
t=text5
carac=sum(len(w) for w in t)
carac
# Out:
# 158114

# %%
long=len(t)

# %%
type(text5)
# Out:
# nltk.text.Text

# %% [markdown]
# #### promedio de longitud de una palabra = suma(longitud de cada palabra)/total de palabras

# %%
carac/long ##esto es el promedio de la longitud d elas palabras
# Out:
# 3.512863808042657

# %% [markdown]
# ## Cap 1. punto 28 Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
fdist=FreqDist(text5)
x=fdist["hugs"] ##ejemplo este me dice que la palabra hugs aparece en el texto 18 veces
x
# Out:
# 18

# %%
def percent(word,text):
    fdist=FreqDist(text)
    ct=fdist[word]
    total=len(text)
    percent=ct/total
    print( str(word), "appears", str(percent) + "% in ", str(text))

# %%
percent("hugs",text5)
# Out:
# hugs appears 0.0003999111308598089% in  <Text: Chat Corpus>

# %%
percent("JOIN",text5)
# Out:
# JOIN appears 0.022683848033770274% in  <Text: Chat Corpus>

# %% [markdown]
# ## Cap 2. punto 2 ☼ Use the corpus module to explore austen-persuasion.txt. How many word tokens does this book have? How many word types?

# %%
from nltk.corpus import gutenberg
austen =gutenberg.words('austen-persuasion.txt')

# %%
len(austen)
# Out:
# 98171

# %%
len(set((w.lower() for w in austen if w.isalpha())))
# Out:
# 5739

# %% [markdown]
# ## Cap 2. punto 4 ☼ Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?

# %%
import nltk
from nltk.corpus import inaugural
dist = nltk.ConditionalFreqDist((target, fileid[:4]) for fileid in inaugural.fileids() for w in inaugural.words(fileid) for target in ['men', 'women', 'people'] if w.lower().startswith(target))
dist.plot()

##extraigo los años usando fileid[:4] osea solo las 3 primeras posiciones de caa titulo de los discursos
##despues digo que me sauqe para cada uno de los 50 discuros, para cada una de las palabras y para los objetos, hombre, mujer, gente

# %% [markdown]
# ## Cap2. punto 11. Investigate the table of modal distributions and look for other patterns. Try to explain them in terms of your own impressionistic understanding of the different genres. Can you find other closed classes of words that exhibit significant differences across different genres?

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
cfd = nltk.ConditionalFreqDist((genre, word)
       for genre in brown.categories()
       for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %% [markdown]
# aperentemente el verbo modal que mas se usa en las noticias es Will lo cual es raro porque las noticias deberian contar cosas que ya pasaron no que van a pasar. en romance el mas comun es could porque son mas formales. pero donde mas usan verbos modales en la categoria de hobies lo cual es muy raro porque no se que tipo de etextos puedan ir en estas categorias

# %%
cfd = nltk.ConditionalFreqDist((genre, word)
       for genre in brown.categories()
       for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['what', 'where', 'when', 'why', 'which']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                  what where  when   why which
#            news    76    58   128     9   244
#        religion    64    20    53    14   202
#         hobbies    78    72   119    10   252
# science_fiction    27    10    21     4    32
#         romance   121    54   126    34   104
#           humor    36    15    52     9    62

# %% [markdown]
# en romance la palabra que mas se usa es when osea cuando supongo porque siempre habla como de estar separados y cuando se van a ver o cosas asi, aparte de la categorias de romance en todas las demas la palabra que mas se usa es which
